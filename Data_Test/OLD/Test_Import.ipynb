# %%
from pathlib import Path
import pandas as pd

# %%
data1 = Path('Data/TA_Data_V.1.csv')
TA_df = pd.read_csv(data1)
TA_df.head(20)
# Out:
#                Date TA.Charge.BPD   TA.OH.PSIG   TA.Tray4.F      TA.OH.F  \
# 0    7/16/2022 0:00   10361.14844  99.02496338  134.8617554  132.9488068
# 1   7/15/2022 23:00   10826.59668  99.44343567  135.1633759  133.4325104
# 2   7/15/2022 22:00    10639.2666  99.98550415  135.0443573  133.3379059
# 3   7/15/2022 21:00   10763.38965     99.21875  134.6079559  132.9411774
# 4   7/15/2022 20:00   10533.08594   101.971817  136.5422516  134.8032684
# 5   7/15/2022 19:00   10713.36914   102.545166  136.9542389  135.2330475
# 6   7/15/2022 18:00   11352.70117  106.4056473  139.4241333  137.8768921
# 7   7/15/2022 17:00   12178.02344  102.9903488  137.2004242  135.3500366
# 8   7/15/2022 16:00   10719.50684  99.33776855   134.552002   133.190918
# 9   7/15/2022 15:00    10246.7959  99.27940369  134.5962524  132.8104706
# 10  7/15/2022 14:00   10537.40918  98.75984192  134.2681885   132.661438
# 11  7/15/2022 13:00    10731.7002  99.30152893  134.6903534  133.1420898
# ...

# %%
data2 = Path('Data/LAB_Data_V.1.csv')
LAB_df = pd.read_csv(data2)
LAB_df.head(20)
# Out:
#                Date  TA.OVH.RECYCLE.NC4.VOLPCT
# 0    7/16/2022 6:00                       11.0
# 1   7/15/2022 13:00                       11.2
# 2    7/15/2022 6:00                       13.9
# 3   7/14/2022 13:00                       13.6
# 4    7/14/2022 6:00                       11.0
# 5   7/13/2022 13:00                       10.7
# 6    7/13/2022 6:00                       11.0
# 7   7/12/2022 13:00                       14.7
# 8    7/12/2022 6:00                       10.8
# 9   7/11/2022 13:00                       14.3
# 10   7/11/2022 6:00                       10.9
# 11  7/10/2022 13:00                        8.1
# 12   7/10/2022 6:00                       11.5
# 13   7/9/2022 13:00                       15.6
# 14    7/9/2022 6:00                       10.6
# 15   7/8/2022 13:00                       10.6
# 16    7/8/2022 6:00                       14.2
# 17   7/7/2022 13:00                        8.2
# 18    7/7/2022 6:00                       16.9
# ...

# %%
# TA_df and LAB_df
df3 = TA_df.merge(LAB_df, on="Date", how='inner')
df3.head(15)

# How to impute values, fill in null values with something that makes sense 
# Arima is a statistical data model
# Try taking time out of this for imput
# T
# Out:
#                Date TA.Charge.BPD   TA.OH.PSIG   TA.Tray4.F      TA.OH.F  \
# 0   7/15/2022 13:00    10731.7002  99.30152893  134.6903534  133.1420898
# 1    7/15/2022 6:00    10332.8252  99.47181702  134.7993469  133.2794189
# 2   7/14/2022 13:00   9904.880859  98.97205353  134.3727112  132.7810669
# 3    7/14/2022 6:00   9641.806641  99.94731903  134.9676514  133.2887726
# 4   7/13/2022 13:00   9876.027344  99.60662842  135.2410889  133.3068848
# 5    7/13/2022 6:00   9299.680664  99.72805023  135.0397186  133.2513885
# 6   7/12/2022 13:00   11581.29199  97.74074554  134.7450256  132.3776245
# 7    7/12/2022 6:00    10984.1123  100.2275848  135.6558228  133.5470581
# 8   7/11/2022 13:00   11691.02734  101.8691254  136.6424561  134.3603516
# 9    7/11/2022 6:00   10511.16699  100.4619598  135.4804993  133.3788605
# 10  7/10/2022 13:00   10214.21973   101.761055  136.8278503  134.5888824
# 11   7/10/2022 6:00   10619.78613  102.9772568  137.3912048  135.5601501
# ...
