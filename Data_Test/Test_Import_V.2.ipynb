# %%
from pathlib import Path
import pandas as pd

# %%
data1 = Path('Data/TA_Data_V.2.csv')
TA_df = pd.read_csv(data1)
TA_df.head(100)
# Out:
#                Date TA.LAB.NC4.VOLPCT TA.Charge.BPD   TA.OH.PSIG   TA.Tray4.F  \
# 0   7/15/2022 13:00             11.20    10731.7002  99.30152893  134.6903534
# 1    7/15/2022 6:00             13.90    10332.8252  99.47181702  134.7993469
# 2   7/14/2022 13:00             13.60   9904.880859  98.97205353  134.3727112
# 3    7/14/2022 6:00             11.00   9641.806641  99.94731903  134.9676514
# 4   7/13/2022 13:00             10.70   9876.027344  99.60662842  135.2410889
# ..              ...               ...           ...          ...          ...
# 95   5/22/2022 6:00             12.50   10455.67676   100.753212  135.8947754
# 96  5/21/2022 13:00             13.30   11526.30859  100.0505829  135.3607178
# 97   5/21/2022 6:00             12.60     10227.375  100.9307861  135.9320068
# 98  5/20/2022 13:00             12.30   11750.56445  99.74266052   134.843399
# 99   5/20/2022 6:00             10.50   10136.71094  99.56748962  134.6414185
#
# ...

# %%
len(TA_df)
# Out:
# 15589

# %%
# Clean TA_df Data 
# Import "other" data source and clean - Weather?
# Import "other" plant data and clean - RX, TB, TC
# Publish clean data sets to SQL
# Pull SQL data to Pandas DF
# Determine variable correlation - chose best variables
# Determine regression model - Linear Regression / Piece Wise Regression
# Train Test Split data
# Note Model Output Performance
# Fine Tune Model
# Use Model to predict "new" datasets - 7/16+
# Create Flask App to share model prediction (really cool if we can upload dataset csv's and the flask app will return predictions)

# %%
# Get all column names
columns = list(TA_df.columns)
print(columns)
# Out:
# ['Date', 'TA.LAB.NC4.VOLPCT', 'TA.Charge.BPD', 'TA.OH.PSIG', 'TA.Tray4.F', 'TA.OH.F', 'TA.RECV.PCT', 'TA.RECV.PSIG', 'TA.REFLUX.BPD', 'TA.RECYCLE.TO.CONTACT.BPD', 'TA.RECYCLE.TO.CONTACT.F', 'TA.TRAY39.F', 'TA.TRAY45.F', 'TA.DP.PSIG', 'TA.BTM.PSIG', 'TA.BTM.LEVEL.PCT', 'TA.BTM.REBOIL.OUT.F', 'TA.TOP.REBOIL.OUT.F']

# %%
# Clean data, drop BAD
# TA_df[TA_df['TA.Charge.BPD'].str.contains("Bad")==False]
# TA_df[TA_df['TA.LAB.NC4.VOLPCT'].str.contains("Bad")==False]
# TA_df[TA_df['TA.OH.PSIG'].str.contains("Bad")==False]
# TA_df[TA_df['TA.Tray4.F'].str.contains("Bad")==False]
# TA_df[TA_df['TA.OH.F'].str.contains("Bad")==False]
# TA_df[TA_df['TA.RECV.PCT'].str.contains("Bad")==False]
# TA_df[TA_df['TA.RECV.PSIG'].str.contains("Bad")==False]
# TA_df[TA_df['TA.REFLUX.BPD'].str.contains("Bad")==False]
# TA_df[TA_df['TA.RECYCLE.TO.CONTACT.BPD'].str.contains("Bad")==False]
# TA_df[TA_df['TA.RECYCLE.TO.CONTACT.F'].str.contains("Bad")==False]
# TA_df[TA_df['TA.TRAY39.F'].str.contains("Bad")==False]
# TA_df[TA_df['TA.TRAY45.F'].str.contains("Bad")==False]
# TA_df[TA_df['TA.DP.PSIG'].str.contains("Bad")==False]
# TA_df[TA_df['TA.BTM.PSIG'].str.contains("Bad")==False]
# TA_df[TA_df['TA.BTM.LEVEL.PCT'].str.contains("Bad")==False]
# TA_df[TA_df['TA.BTM.REBOIL.OUT.F'].str.contains("Bad")==False]
# TA_df[TA_df['TA.TOP.REBOIL.OUT.F'].str.contains("Bad")==False]
TA_df.describe()
# Out:
#                  Date TA.LAB.NC4.VOLPCT TA.Charge.BPD TA.OH.PSIG   TA.Tray4.F  \
# count           15589             15589         15589      15589        15589
# unique          14183               299         11582       5670         5781
# top     1/2/2019 6:00              9.60         Error        Bad  134.7381592
# freq                3               719            28        457           34
#
#        TA.OH.F   TA.RECV.PCT TA.RECV.PSIG TA.REFLUX.BPD  \
# count    15589         15589        15589         15589
# unique    5854         13826         5685         11114
# top        Bad  -6.900000095   100.033577     Bad Input
# freq        85           586           73            51
#
#        TA.RECYCLE.TO.CONTACT.BPD TA.RECYCLE.TO.CONTACT.F TA.TRAY39.F  \
# count                      15589                   15589       15589
# unique                      7279                   10656        7828
# top                          Bad                   Error       Error
# ...

# %% [markdown]
# Linear Regression Test

# %%
 ## Separate the Features (X) from the Target (y)
y = TA_df["TA.LAB.NC4.VOLPCT"]
X = TA_df.drop(["TA.LAB.NC4.VOLPCT", "Date"], axis = 1)

#print(y)
#print(X)
X.describe()
# Out:
#        TA.Charge.BPD TA.OH.PSIG   TA.Tray4.F TA.OH.F   TA.RECV.PCT  \
# count          15589      15589        15589   15589         15589
# unique         11582       5670         5781    5854         13826
# top            Error        Bad  134.7381592     Bad  -6.900000095
# freq              28        457           34      85           586
#
#        TA.RECV.PSIG TA.REFLUX.BPD TA.RECYCLE.TO.CONTACT.BPD  \
# count         15589         15589                     15589
# unique         5685         11114                      7279
# top      100.033577     Bad Input                       Bad
# freq             73            51                       313
#
#        TA.RECYCLE.TO.CONTACT.F TA.TRAY39.F TA.TRAY45.F TA.DP.PSIG TA.BTM.PSIG  \
# count                    15589       15589       15589      15589       15589
# unique                   10656        7828        7916       5770        6656
# top                      Error       Error       Error        Bad  102.355957
# ...

# %%
## Split into train data and test data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=0)
X_train.shape
# Out:
# (11691, 16)

# %%
# Import Linear Regression Model
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# Train the model
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/brenton/Desktop/Vanderbilt Data Analysis/Project/Red-ProjectHub/Data_Test/Test_Import_V.2.ipynb Cell 12 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/brenton/Desktop/Vanderbilt%20Data%20Analysis/Project/Red-ProjectHub/Data_Test/Test_Import_V.2.ipynb#ch0000008?line=0'>1</a> # Train the model
# ----> <a href='vscode-notebook-cell:/Users/brenton/Desktop/Vanderbilt%20Data%20Analysis/Project/Red-ProjectHub/Data_Test/Test_Import_V.2.ipynb#ch0000008?line=1'>2</a> model.fit(X_train, y_train)
#
# File ~/opt/anaconda3/envs/mlenv3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:662, in LinearRegression.fit(self, X, y, sample_weight)
#     658 n_jobs_ = self.n_jobs
#     660 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 662 X, y = self._validate_data(
# ...
