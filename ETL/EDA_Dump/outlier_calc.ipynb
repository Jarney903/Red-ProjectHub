# %%
# Import Dependencies
import pandas as pd
import numpy as np

# %%
# load data

file = pd.read_csv("Resources/ta_pass_1.csv", index_col=[0])
tower_a = pd.DataFrame(file)
#tower_a = tower_a.drop(columns=['Date'])
tower_a
# Out:
#                  Date  TA.LAB.NC4.VOLPCT  TA.Charge.BPD  TA.OH.PSIG  \
# 0     7/15/2022 13:00               11.2   10731.700200   99.301529
# 1      7/15/2022 6:00               13.9   10332.825200   99.471817
# 2     7/14/2022 13:00               13.6    9904.880859   98.972054
# 3      7/14/2022 6:00               11.0    9641.806641   99.947319
# 4     7/13/2022 13:00               10.7    9876.027344   99.606628
# ...               ...                ...            ...         ...
# 4468    1/6/2013 6:00               18.0   25122.466800   92.152405
# 4469   1/5/2013 13:00               14.4   25195.296880  101.445007
# 4470    1/5/2013 6:00               10.2   24632.414060   94.033821
# 4471   1/4/2013 13:00                6.1   24166.078130   95.306396
# 4472    1/4/2013 6:00                4.9   19465.988280  102.985382
#
#       TA.Tray4.F     TA.OH.F  TA.RECV.PCT  TA.RECV.PSIG  TA.REFLUX.BPD  \
# 0     134.690353  133.142090     1.432773    100.622315    5919.916992
# ...

# %%
# confirm datatypes are floats

tower_a.dtypes
# Out:
# Date                          object
# TA.LAB.NC4.VOLPCT            float64
# TA.Charge.BPD                float64
# TA.OH.PSIG                   float64
# TA.Tray4.F                   float64
# TA.OH.F                      float64
# TA.RECV.PCT                  float64
# TA.RECV.PSIG                 float64
# TA.REFLUX.BPD                float64
# TA.RECYCLE.TO.CONTACT.BPD    float64
# TA.RECYCLE.TO.CONTACT.F      float64
# TA.TRAY39.F                  float64
# TA.TRAY45.F                  float64
# TA.DP.PSIG                   float64
# TA.BTM.PSIG                  float64
# TA.BTM.LEVEL.PCT             float64
# TA.BTM.REBOIL.OUT.F          float64
# TA.TOP.REBOIL.OUT.F          float64
# dtype: object

# %%
# summary stats for Tower A

tower_a.describe()
# Out:
#        TA.LAB.NC4.VOLPCT  TA.Charge.BPD   TA.OH.PSIG   TA.Tray4.F  \
# count        4473.000000    4473.000000  4473.000000  4473.000000
# mean           11.065623   15682.922180    97.651869   134.139814
# std            15.551509    4363.325646     6.629951     3.669092
# min             0.000000       0.000000    -1.532560    96.229553
# 25%             8.200000   12182.952150    96.906281   132.400513
# 50%            10.200000   15720.031250    97.400665   133.926392
# 75%            12.600000   18020.111330    99.456024   135.294525
# max          1005.000000   29901.033200   133.076477   194.899170
#
#            TA.OH.F  TA.RECV.PCT  TA.RECV.PSIG  TA.REFLUX.BPD  \
# count  4473.000000  4473.000000   4473.000000    4473.000000
# mean    131.508497     9.213272    100.148625    7000.075623
# std       4.062976     9.011683      4.644076    1316.201403
# min      96.133430    -6.900000     54.655460    -836.645019
# 25%     129.504394     6.567385     99.557503    6371.229980
# ...

# %%
#max_butane = tower_a.loc[tower_a['TA.LAB.NC4.VOLPCT'] >= 30]
#max_butane

# %% [markdown]
# - q1 = df['feature n'].quantile(0.25)
# - q3 = df['feature n'].quantile(.75)
# - iqr = q3-q1
# - lower_lim_n = q1 - (1.5 * iqr)
# - upper_lim_n = q3 + (1.5 * iqr)

# %% [markdown]
# #### Plan
# - identify upper and lower limits for each feature and isolate the outliers
# - check the rows that contain the outliers
# - drop as needed/impute with mean values?
# - document the excluded outliers and explain reasoning
# - run ml with and without outliers and compare

# %%
# outlier identification function

def find_outliers(df):
    q1 = df.quantile(0.25)
    q3 = df.quantile(.75)
    iqr = q3-q1
    lower_lim = q1 - (1.5 * iqr)
    upper_lim = q3 + (1.5 * iqr)
    outliers = df[((df<lower_lim) | (df>upper_lim))]
    return outliers

# %%
a_outliers = find_outliers(tower_a)
a_outliers.describe()
#a_outliers
# Out:
# C:\Users\anna\AppData\Local\Temp/ipykernel_21564/2126452965.py:9: FutureWarning: Automatic reindexing on DataFrame vs Series comparisons is deprecated and will raise ValueError in a future version.  Do `left, right = left.align(right, axis=1, copy=False)` before e.g. `left == right`
#   outliers = df[((df<lower_lim) | (df>upper_lim))]
#        TA.LAB.NC4.VOLPCT  TA.Charge.BPD  TA.OH.PSIG  TA.Tray4.F     TA.OH.F  \
# count         194.000000      59.000000  977.000000  328.000000  284.000000
# mean           25.961340   21119.411890   96.118909  139.384977  133.449297
# std            71.771083   12356.300851   13.723729    9.519077   12.087410
# min             0.000000       0.000000   -1.532560   96.229553   96.133430
# 25%            19.800000   14668.096072   92.136383  139.758526  122.874458
# 50%            21.650000   27647.812500   92.511749  141.610718  139.428711
# 75%            26.050000   28898.911130  104.942322  143.737030  141.236877
# ...

# %% [markdown]
# Expected Measures
# - focus on temperature and pressure
#
# - TA.LAB.NC4.VOLPCT < 40
# - TA.Charge.BPD > 5000
# - TA.OH.PSIG bust into and check (minimum indicates vacuum, expecting: 10 lbs of OH pressure: 10 PSIG, mean is 96 PSIG, we need to understand this better)
# - TA.Tray4.F > 100 F
# - TA.OH.F > 100
# - TA.RECV.PCT 0-100, all else is invalid
# - TA.RECV.PSIG need to understand better
# - TA.REFLUX.BPD : can't really trust the reflux meter (industry wide), should not be below 0 or it indicates a problem
# - TA.RECYCLE.TO.CONTACT.BPD	TA.RECYCLE.TO.CONTACT.F, this is where the Butane comes through, so important feature, should not be negative, avg expected around 6-10 K
# - DP not above 10 PSIG
#     - OH pressure minus BTM pressure should roughly = Differential Pressure

# %% [markdown]
# TA.BTM.REBOIL.OUT.F	TA.TOP.REBOIL.OUT.F, seems pretty good, don't focus too much on cleaning outliers from here
#
# Recommendations: drop the PCT features and the REFLUX

# %%
# drop overhead pressure
# drop bottom pressure
# drop recieved percent
# drop bottom pressure percent
# drop reflux
