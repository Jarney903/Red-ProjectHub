# %%
# Import Dependencies
import pandas as pd
import numpy as np

# %%
# load data

file = pd.read_csv("Resources/ta_pass_1.csv", index_col=[0])
tower_a = pd.DataFrame(file)
tower_a = tower_a.drop(columns=['Date'])
tower_a
# Out:
#       TA.LAB.NC4.VOLPCT  TA.Charge.BPD  TA.OH.PSIG  TA.Tray4.F     TA.OH.F  \
# 0                  11.2   10731.700200   99.301529  134.690353  133.142090
# 1                  13.9   10332.825200   99.471817  134.799347  133.279419
# 2                  13.6    9904.880859   98.972054  134.372711  132.781067
# 3                  11.0    9641.806641   99.947319  134.967651  133.288773
# 4                  10.7    9876.027344   99.606628  135.241089  133.306885
# ...                 ...            ...         ...         ...         ...
# 4468               18.0   25122.466800   92.152405  127.703857  120.507812
# 4469               14.4   25195.296880  101.445007  133.221436  126.837158
# 4470               10.2   24632.414060   94.033821  128.207398  121.832275
# 4471                6.1   24166.078130   95.306396  127.667236  122.308350
# 4472                4.9   19465.988280  102.985382  131.030273  126.440430
#
# ...

# %%
# isolate features
#X = tower_a.drop(columns=['TA.LAB.NC4.VOLPCT'])

# isolate target
#y = tower_a['TA.LAB.NC4.VOLPCT']

# %%
#X.describe()

# %%
# calculating outlier thresholds for each feature
