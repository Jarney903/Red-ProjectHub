# %%
# necessary imports

import pandas as pd
import numpy as np

# %%
# loading files and converting into dataframes

file1 = pd.read_csv("Resources/lab_clean-Copy1.csv", index_col=[0])
file2 = pd.read_csv("Resources/ta_pass_02-Copy1.csv", index_col=[0])

lab_data = pd.DataFrame(file1)
ta_clean = pd.DataFrame(file2)

# %%
# check if properly loaded
lab_data.head()
# Out:
#             Date  TA.OVH.RECYCLE.NC4.VOLPCT
# 0  7/15/22 13:00                       11.2
# 1   7/15/22 6:00                       13.9
# 2  7/14/22 13:00                       13.6
# 3   7/14/22 6:00                       11.0
# 4  7/13/22 13:00                       10.7

# %%
# change date column to datetime "Time" column for the purpose of quickly 
# dropping unwanted data by dates later
# as well as an easy merge
lab_data['Time'] = pd.to_datetime(lab_data['Date'])
lab_data = lab_data.drop(columns=['Date'])
lab_data
# Out:
#        TA.OVH.RECYCLE.NC4.VOLPCT                Time
# 0                           11.2 2022-07-15 13:00:00
# 1                           13.9 2022-07-15 06:00:00
# 2                           13.6 2022-07-14 13:00:00
# 3                           11.0 2022-07-14 06:00:00
# 4                           10.7 2022-07-13 13:00:00
# ...                          ...                 ...
# 15584                       18.0 2013-01-06 06:00:00
# 15585                       14.4 2013-01-05 13:00:00
# 15586                       10.2 2013-01-05 06:00:00
# 15587                        6.1 2013-01-04 13:00:00
# 15588                        4.9 2013-01-04 06:00:00
#
# [15589 rows x 2 columns]

# %%
# checking Tower A data loaded correctly
ta_clean.head()
# Out:
#               Date  TA.Charge.BPD  TA.OH.PSIG  TA.Tray4.F     TA.OH.F  \
# 0  7/15/2022 13:00   10731.700200   99.301529  134.690353  133.142090
# 1   7/15/2022 6:00   10332.825200   99.471817  134.799347  133.279419
# 2  7/14/2022 13:00    9904.880859   98.972054  134.372711  132.781067
# 3   7/14/2022 6:00    9641.806641   99.947319  134.967651  133.288773
# 4  7/13/2022 13:00    9876.027344   99.606628  135.241089  133.306885
#
#    TA.RECV.PCT  TA.RECV.PSIG  TA.REFLUX.BPD  TA.RECYCLE.TO.CONTACT.BPD  \
# 0     1.432773    100.622315    5919.916992                6399.555664
# 1     3.479724     99.484406    5935.238281                6395.504883
# 2     2.860878     99.419403    5968.467773                5933.965332
# 3     4.899298     99.858498    6020.976074                5902.112793
# 4     1.202636    100.433968    5917.750488                5749.198730
#
#    TA.RECYCLE.TO.CONTACT.F  TA.TRAY39.F  TA.TRAY45.F  TA.DP.PSIG  TA.BTM.PSIG  \
# ...

# %%
# changing date column to Time column in datetime format
ta_clean['Time'] = pd.to_datetime(ta_clean['Date'])

# %%
# dropping the now redundant Date column
ta_clean = ta_clean.drop(columns=['Date'])
ta_clean
# Out:
#       TA.Charge.BPD  TA.OH.PSIG  TA.Tray4.F     TA.OH.F  TA.RECV.PCT  \
# 0      10731.700200   99.301529  134.690353  133.142090     1.432773
# 1      10332.825200   99.471817  134.799347  133.279419     3.479724
# 2       9904.880859   98.972054  134.372711  132.781067     2.860878
# 3       9641.806641   99.947319  134.967651  133.288773     4.899298
# 4       9876.027344   99.606628  135.241089  133.306885     1.202636
# ...             ...         ...         ...         ...          ...
# 5338   25122.466800   92.152405  127.703857  120.507812     8.922233
# 5339   25195.296880  101.445007  133.221436  126.837158    -6.900000
# 5340   24632.414060   94.033821  128.207398  121.832275    -6.900000
# 5341   24166.078130   95.306396  127.667236  122.308350    -6.900000
# 5342   19465.988280  102.985382  131.030273  126.440430    -6.900000
#
#       TA.RECV.PSIG  TA.REFLUX.BPD  TA.RECYCLE.TO.CONTACT.BPD  \
# 0       100.622315    5919.916992                6399.555664
# ...

# %%
# merge the dataframes on 'Time' column
lab_ta = ta_clean.merge(lab_data, on='Time')

# %%
# check if properly merged
lab_ta
# Out:
#       TA.Charge.BPD  TA.OH.PSIG  TA.Tray4.F     TA.OH.F  TA.RECV.PCT  \
# 0      10731.700200   99.301529  134.690353  133.142090     1.432773
# 1      10332.825200   99.471817  134.799347  133.279419     3.479724
# 2       9904.880859   98.972054  134.372711  132.781067     2.860878
# 3       9641.806641   99.947319  134.967651  133.288773     4.899298
# 4       9876.027344   99.606628  135.241089  133.306885     1.202636
# ...             ...         ...         ...         ...          ...
# 4432   25122.466800   92.152405  127.703857  120.507812     8.922233
# 4433   25195.296880  101.445007  133.221436  126.837158    -6.900000
# 4434   24632.414060   94.033821  128.207398  121.832275    -6.900000
# 4435   24166.078130   95.306396  127.667236  122.308350    -6.900000
# 4436   19465.988280  102.985382  131.030273  126.440430    -6.900000
#
#       TA.RECV.PSIG  TA.REFLUX.BPD  TA.RECYCLE.TO.CONTACT.BPD  \
# 0       100.622315    5919.916992                6399.555664
# ...

# %%
# needed to easily pull column names for quick reordering
lab_ta.columns
# Out:
# Index(['TA.Charge.BPD', 'TA.OH.PSIG', 'TA.Tray4.F', 'TA.OH.F', 'TA.RECV.PCT',
#        'TA.RECV.PSIG', 'TA.REFLUX.BPD', 'TA.RECYCLE.TO.CONTACT.BPD',
#        'TA.RECYCLE.TO.CONTACT.F', 'TA.TRAY39.F', 'TA.TRAY45.F', 'TA.DP.PSIG',
#        'TA.BTM.PSIG', 'TA.BTM.LEVEL.PCT', 'TA.BTM.REBOIL.OUT.F',
#        'TA.TOP.REBOIL.OUT.F', 'Time', 'TA.OVH.RECYCLE.NC4.VOLPCT'],
#       dtype='object')

# %%
# reording columns so that what will be our target feature is at the end
lab_ta = lab_ta[['Time','TA.Charge.BPD', 'TA.OH.PSIG', 'TA.Tray4.F', 'TA.OH.F', 'TA.RECV.PCT',
       'TA.RECV.PSIG', 'TA.REFLUX.BPD', 'TA.RECYCLE.TO.CONTACT.BPD',
       'TA.RECYCLE.TO.CONTACT.F', 'TA.TRAY39.F', 'TA.TRAY45.F', 'TA.DP.PSIG',
       'TA.BTM.PSIG', 'TA.BTM.LEVEL.PCT', 'TA.BTM.REBOIL.OUT.F',
       'TA.TOP.REBOIL.OUT.F','TA.OVH.RECYCLE.NC4.VOLPCT']]

# %%
# checking if reordering worked
lab_ta
# Out:
#                     Time  TA.Charge.BPD  TA.OH.PSIG  TA.Tray4.F     TA.OH.F  \
# 0    2022-07-15 13:00:00   10731.700200   99.301529  134.690353  133.142090
# 1    2022-07-15 06:00:00   10332.825200   99.471817  134.799347  133.279419
# 2    2022-07-14 13:00:00    9904.880859   98.972054  134.372711  132.781067
# 3    2022-07-14 06:00:00    9641.806641   99.947319  134.967651  133.288773
# 4    2022-07-13 13:00:00    9876.027344   99.606628  135.241089  133.306885
# ...                  ...            ...         ...         ...         ...
# 4432 2013-01-06 06:00:00   25122.466800   92.152405  127.703857  120.507812
# 4433 2013-01-05 13:00:00   25195.296880  101.445007  133.221436  126.837158
# 4434 2013-01-05 06:00:00   24632.414060   94.033821  128.207398  121.832275
# 4435 2013-01-04 13:00:00   24166.078130   95.306396  127.667236  122.308350
# 4436 2013-01-04 06:00:00   19465.988280  102.985382  131.030273  126.440430
#
# ...

# %%
# checking that the data types are floats
lab_ta.dtypes
# Out:
# Time                         datetime64[ns]
# TA.Charge.BPD                       float64
# TA.OH.PSIG                          float64
# TA.Tray4.F                          float64
# TA.OH.F                             float64
# TA.RECV.PCT                         float64
# TA.RECV.PSIG                        float64
# TA.REFLUX.BPD                       float64
# TA.RECYCLE.TO.CONTACT.BPD           float64
# TA.RECYCLE.TO.CONTACT.F             float64
# TA.TRAY39.F                         float64
# TA.TRAY45.F                         float64
# TA.DP.PSIG                          float64
# TA.BTM.PSIG                         float64
# TA.BTM.LEVEL.PCT                    float64
# TA.BTM.REBOIL.OUT.F                 float64
# TA.TOP.REBOIL.OUT.F                 float64
# TA.OVH.RECYCLE.NC4.VOLPCT           float64
# dtype: object

# %%
# summary statistics of merged dataframe
lab_ta.describe()
# Out:
#        TA.Charge.BPD   TA.OH.PSIG   TA.Tray4.F      TA.OH.F  TA.RECV.PCT  \
# count    4437.000000  4437.000000  4437.000000  4437.000000  4437.000000
# mean    15620.672366    97.723350   134.151958   131.517451     9.289621
# std      4263.920510     6.221024     3.588488     4.004188     8.999482
# min         0.000000    -1.532560   102.691650   102.038574    -6.900000
# 25%     12188.400390    96.929169   132.424927   129.528809     6.722509
# 50%     15695.221680    97.400665   133.936645   131.686401     9.929183
# 75%     17976.638670    99.451538   135.272217   133.261917    13.606541
# max     29810.134770   133.076477   194.899170   194.660858   105.000000
#
#        TA.RECV.PSIG  TA.REFLUX.BPD  TA.RECYCLE.TO.CONTACT.BPD  \
# count   4437.000000    4437.000000                4437.000000
# mean     100.181026    6990.922152                6726.168323
# std        4.536183    1307.468604                 989.504336
# ...

# %%
# export cleaned data as ta_pass_03.csv
#lab_ta.to_csv("Resources/ta_pass_03.csv")

# %%
# outlier identification function

def find_outliers(df):
    q1 = df.quantile(0.25)
    q3 = df.quantile(.75)
    iqr = q3-q1
    lower_lim = q1 - (1.5 * iqr)
    upper_lim = q3 + (1.5 * iqr)
    outliers = df[((df<lower_lim) | (df>upper_lim))]
    return outliers

# %%
# making a separate df to hold outlier information
test_df = lab_ta.drop(columns=['Time'])

outliers = find_outliers(test_df)
outliers
# Out:
#       TA.Charge.BPD  TA.OH.PSIG  TA.Tray4.F     TA.OH.F  TA.RECV.PCT  \
# 0               NaN         NaN         NaN         NaN          NaN
# 1               NaN         NaN         NaN         NaN          NaN
# 2               NaN         NaN         NaN         NaN          NaN
# 3               NaN         NaN         NaN         NaN          NaN
# 4               NaN         NaN         NaN         NaN          NaN
# ...             ...         ...         ...         ...          ...
# 4432            NaN   92.152405  127.703857  120.507812          NaN
# 4433            NaN         NaN         NaN         NaN         -6.9
# 4434            NaN         NaN         NaN  121.832275         -6.9
# 4435            NaN         NaN  127.667236  122.308350         -6.9
# 4436            NaN         NaN         NaN         NaN         -6.9
#
#       TA.RECV.PSIG  TA.REFLUX.BPD  TA.RECYCLE.TO.CONTACT.BPD  \
# 0              NaN            NaN                        NaN
# ...

# %%
# summary statistics on outliers
outliers.describe()
# Out:
#        TA.Charge.BPD  TA.OH.PSIG  TA.Tray4.F     TA.OH.F  TA.RECV.PCT  \
# count      41.000000  949.000000  336.000000  287.000000   664.000000
# mean    17700.180372   96.437474  139.470569  133.392917    -0.983747
# std     13488.224614   12.995649    8.961749   11.773135    16.962280
# min         0.000000   -1.532560  102.691650  102.038574    -6.900000
# 25%        43.794273   92.136383  139.623451  122.892765    -6.900000
# 50%     26958.464840   92.500305  141.502380  139.385986    -6.900000
# 75%     27801.376950  105.022430  143.533325  141.192627    -6.900000
# max     29810.134770  133.076477  194.899170  194.660858   105.000000
#
#        TA.RECV.PSIG  TA.REFLUX.BPD  TA.RECYCLE.TO.CONTACT.BPD  \
# count   1538.000000     172.000000                 814.000000
# mean     100.473771    4308.519581                7986.333103
# std        7.677170    3383.735933                1752.429110
# min       57.708740    -836.645019                   0.000000
# ...

# %% [markdown]
# - may want to cap the outliers, decide what needs to be dropped, and what can be kept
# - first need to run some tests to see feature importances, so that I can avoid getting rid of whole rows when I can get rid of unimportant features (that may contain many of the outliers) instead
