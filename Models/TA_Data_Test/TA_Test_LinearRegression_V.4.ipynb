# %%
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

data1 = Path('Data/TA_Data_V.2.csv')
TA_df = pd.read_csv(data1)

# Clean

# Outliers - TA Dates 10/1/2018 - 5/1/2019 1859-12038 indexes are turnaround bad data
TA_df = TA_df.drop(index=TA_df.index[1859:12038])
TA_df

# Remove Charge Outliers TA.Charge.BPD > 8000 < 20000
TA_df = TA_df.drop(TA_df[(TA_df['TA.Charge.BPD'] > '5000') & (TA_df['TA.Charge.BPD'] < '30000')].index)
TA_df

# Clean data, drop BAD
TA_df = TA_df[TA_df['TA.Charge.BPD'].str.contains("Bad")==False]
TA_df = TA_df[TA_df['TA.LAB.NC4.VOLPCT'].str.contains("Bad")==False]
TA_df = TA_df[TA_df['TA.OH.PSIG'].str.contains("Bad")==False]
TA_df = TA_df[TA_df['TA.Tray4.F'].str.contains("Bad")==False]
TA_df = TA_df[TA_df['TA.OH.F'].str.contains("Bad")==False]
TA_df = TA_df[TA_df['TA.RECV.PCT'].str.contains("Bad")==False]
TA_df = TA_df[TA_df['TA.RECV.PSIG'].str.contains("Bad")==False]
TA_df = TA_df[TA_df['TA.REFLUX.BPD'].str.contains("Bad")==False]
TA_df = TA_df[TA_df['TA.RECYCLE.TO.CONTACT.BPD'].str.contains("Bad")==False]
TA_df = TA_df[TA_df['TA.RECYCLE.TO.CONTACT.F'].str.contains("Bad")==False]
TA_df = TA_df[TA_df['TA.TRAY39.F'].str.contains("Bad")==False]
TA_df = TA_df[TA_df['TA.TRAY45.F'].str.contains("Bad")==False]
TA_df = TA_df[TA_df['TA.DP.PSIG'].str.contains("Bad")==False]
TA_df = TA_df[TA_df['TA.BTM.PSIG'].str.contains("Bad")==False]
TA_df = TA_df[TA_df['TA.BTM.LEVEL.PCT'].str.contains("Bad")==False]
TA_df = TA_df[TA_df['TA.BTM.REBOIL.OUT.F'].str.contains("Bad")==False]
TA_df = TA_df[TA_df['TA.TOP.REBOIL.OUT.F'].str.contains("Bad")==False]

# Clean data, drop BAD
TA_df = TA_df[TA_df['TA.Charge.BPD'].str.contains("Error")==False]
TA_df = TA_df[TA_df['TA.LAB.NC4.VOLPCT'].str.contains("Error")==False]
TA_df = TA_df[TA_df['TA.OH.PSIG'].str.contains("Error")==False]
TA_df = TA_df[TA_df['TA.Tray4.F'].str.contains("Error")==False]
TA_df = TA_df[TA_df['TA.OH.F'].str.contains("Error")==False]
TA_df = TA_df[TA_df['TA.RECV.PCT'].str.contains("Error")==False]
TA_df = TA_df[TA_df['TA.RECV.PSIG'].str.contains("Error")==False]
TA_df = TA_df[TA_df['TA.REFLUX.BPD'].str.contains("Error")==False]
TA_df = TA_df[TA_df['TA.RECYCLE.TO.CONTACT.BPD'].str.contains("Error")==False]
TA_df = TA_df[TA_df['TA.RECYCLE.TO.CONTACT.F'].str.contains("Error")==False]
TA_df = TA_df[TA_df['TA.TRAY39.F'].str.contains("Error")==False]
TA_df = TA_df[TA_df['TA.TRAY45.F'].str.contains("Error")==False]
TA_df = TA_df[TA_df['TA.DP.PSIG'].str.contains("Error")==False]
TA_df = TA_df[TA_df['TA.BTM.PSIG'].str.contains("Error")==False]
TA_df = TA_df[TA_df['TA.BTM.LEVEL.PCT'].str.contains("Error")==False]
TA_df = TA_df[TA_df['TA.BTM.REBOIL.OUT.F'].str.contains("Error")==False]
TA_df = TA_df[TA_df['TA.TOP.REBOIL.OUT.F'].str.contains("Error")==False]

# Clean data, drop I/O Timeout
TA_df = TA_df[TA_df['TA.Charge.BPD'].str.contains("I/O Timeout")==False]
TA_df = TA_df[TA_df['TA.LAB.NC4.VOLPCT'].str.contains("I/O Timeout")==False]
TA_df = TA_df[TA_df['TA.OH.PSIG'].str.contains("I/O Timeout")==False]
TA_df = TA_df[TA_df['TA.Tray4.F'].str.contains("I/O Timeout")==False]
TA_df = TA_df[TA_df['TA.OH.F'].str.contains("I/O Timeout")==False]
TA_df = TA_df[TA_df['TA.RECV.PCT'].str.contains("I/O Timeout")==False]
TA_df = TA_df[TA_df['TA.RECV.PSIG'].str.contains("I/O Timeout")==False]
TA_df = TA_df[TA_df['TA.REFLUX.BPD'].str.contains("I/O Timeout")==False]
TA_df = TA_df[TA_df['TA.RECYCLE.TO.CONTACT.BPD'].str.contains("I/O Timeout")==False]
TA_df = TA_df[TA_df['TA.RECYCLE.TO.CONTACT.F'].str.contains("I/O Timeout")==False]
TA_df = TA_df[TA_df['TA.TRAY39.F'].str.contains("I/O Timeout")==False]
TA_df = TA_df[TA_df['TA.TRAY45.F'].str.contains("I/O Timeout")==False]
TA_df = TA_df[TA_df['TA.DP.PSIG'].str.contains("I/O Timeout")==False]
TA_df = TA_df[TA_df['TA.BTM.PSIG'].str.contains("I/O Timeout")==False]
TA_df = TA_df[TA_df['TA.BTM.LEVEL.PCT'].str.contains("I/O Timeout")==False]
TA_df = TA_df[TA_df['TA.BTM.REBOIL.OUT.F'].str.contains("I/O Timeout")==False]
TA_df = TA_df[TA_df['TA.TOP.REBOIL.OUT.F'].str.contains("I/O Timeout")==False]


# Drop Dates
TA_df = TA_df.drop(['Date'], axis=1)
# Convert all to FLOAT
TA_df = TA_df.astype("float")
TA_df
# Out:
#        TA.LAB.NC4.VOLPCT  TA.Charge.BPD  TA.OH.PSIG  TA.Tray4.F     TA.OH.F  \
# 0                   11.2   10731.700200   99.301529  134.690353  133.142090
# 1                   13.9   10332.825200   99.471817  134.799347  133.279419
# 2                   13.6    9904.880859   98.972054  134.372711  132.781067
# 3                   11.0    9641.806641   99.947319  134.967651  133.288773
# 4                   10.7    9876.027344   99.606628  135.241089  133.306885
# ...                  ...            ...         ...         ...         ...
# 15584               18.0   25122.466800   92.152405  127.703857  120.507812
# 15585               14.4   25195.296880  101.445007  133.221436  126.837158
# 15586               10.2   24632.414060   94.033821  128.207398  121.832275
# 15587                6.1   24166.078130   95.306396  127.667236  122.308350
# 15588                4.9   19465.988280  102.985382  131.030273  126.440430
#
#        TA.RECV.PCT  TA.RECV.PSIG  TA.REFLUX.BPD  TA.RECYCLE.TO.CONTACT.BPD  \
# 0         1.432773    100.622315    5919.916992                6399.555664
# 1         3.479724     99.484406    5935.238281                6395.504883
# 2         2.860878     99.419403    5968.467773                5933.965332
# 3         4.899298     99.858498    6020.976074                5902.112793
# 4         1.202636    100.433968    5917.750488                5749.198730
# ...            ...           ...            ...                        ...
# 15584     8.922233     94.467171    8196.665039                8761.213867
# 15585    -6.900000    103.817757    8516.427734                9015.898438
# 15586    -6.900000     96.345520    8513.540039                8986.914063
# 15587    -6.900000     97.552490    8439.272461                8972.183594
# 15588    -6.900000    105.233772    8512.096680                9469.200195
#
#        TA.RECYCLE.TO.CONTACT.F  TA.TRAY39.F  TA.TRAY45.F  TA.DP.PSIG  \
# 0                    97.036232   160.828659   177.024338    0.669861
# 1                    93.115395   159.833221   175.662384    0.578269
# 2                    97.990959   161.156311   178.832550    0.781860
# 3                    92.662971   159.716385   176.088470    0.605774
# 4                    98.549294   163.994949   182.754105    0.644531
# ...                        ...          ...          ...         ...
# 15584                77.021790   166.543579   186.938477    8.200836
# 15585                89.143372   173.013306   187.103287    8.182526
# 15586                86.091614   167.779556   187.533569    8.205414
# 15587                85.450745   163.192749   187.124634    8.134460
# 15588                85.304260   162.399292   188.204956    8.317566
#
#        TA.BTM.PSIG  TA.BTM.LEVEL.PCT  TA.BTM.REBOIL.OUT.F  TA.TOP.REBOIL.OUT.F
# 0        98.631668         74.778496           315.351349           188.916534
# 1        98.897438         72.928696           312.314453           188.058929
# 2        98.191566         73.682632           318.302307           191.867233
# 3        99.337463         74.873863           312.119537           187.954300
# 4        98.956146         76.232300           318.608795           195.616043
# ...            ...               ...                  ...                  ...
# 15584   100.465393        102.261360           312.414551           246.087662
# 15585   109.625244        101.425179           314.068603           233.258072
# 15586   102.216339        102.111816           312.402344           242.431641
# 15587   103.534699        102.362060           312.939453           247.558594
# 15588   111.231995        101.971435           312.261963           228.198242
#
# [4473 rows x 17 columns]

# %%
### Prep for Plot Charge ###
TA_df2 = TA_df
# Add Date Count
datecount = []
i=0
for date in TA_df2['TA.Charge.BPD']:
    datecount.append(i)
    i=i+1
TA_df2["Date_Count"] = datecount
TA_df2.plot(x ='Date_Count', y='TA.Charge.BPD', kind = 'line')
plt.show()

# %%
 ## Separate the Features (X) from the Target (y)
y = TA_df["TA.LAB.NC4.VOLPCT"]
X = TA_df.drop(["TA.LAB.NC4.VOLPCT"], axis = 1)

## Split into train data and test data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=0)
X_train.shape

# Import Linear Regression Model
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# Train the model
model.fit(X_train, y_train)

# Make Predictions
y_pred = model.predict(X_test)
results = pd.DataFrame({"Prediction": y_pred, "Actual": y_test}).reset_index(drop=True)
results.head(20)
# Out:
#     Prediction  Actual
# 0    14.370488    15.4
# 1    13.358211     8.3
# 2    13.402987    15.2
# 3     2.595654     4.5
# 4    12.039596     8.6
# 5     9.686063     9.4
# 6     8.417249     6.1
# 7    13.873810    15.7
# 8    14.111147    12.5
# 9    10.056216    11.9
# 10   10.145705     7.1
# 11    9.709501    11.5
# 12   11.304262    10.7
# 13   15.060993    12.4
# 14    8.581041     7.9
# 15   15.048949    15.1
# 16   10.478822     7.0
# 17    8.208957     7.9
# 18   12.532309    13.0
# 19    7.173929     9.3

# %%
# Plot Results
# Create X-Axis for y
plot_df=pd.DataFrame(results)
count = []
i=0
for value in plot_df['Actual']:
    count.append(i)
    i=i+1
plot_df["Count"] = count  
plot_df.head()
plot_df["Actual"] = pd.to_numeric(plot_df["Actual"])
plot_df.dtypes
df = plot_df.head(150)
# Plot
ax = df.plot(kind="scatter", x="Count",y="Actual", color="b", label="Actual Results")
df.plot(x="Count",y="Prediction", color="r", label="Predicted Results", ax=ax)


ax.set_xlabel("Days")
ax.set_ylabel("N-Butane Vol%")
ax.set_ylim(0,25)
plt.show()

# %%
results_df = pd.DataFrame(results)
variation = abs(results_df["Actual"] - results_df["Prediction"])
results_df['Variation Vol%']=variation
total_variation = results_df['Variation Vol%'].mean()

accuracy = (results_df["Actual"].astype(float)/results_df["Prediction"].astype(float))*100
results_df['Accuracy']=accuracy
total_accuracy = results_df['Accuracy'].astype(float).mean()

# total_accuracy
print(" The average variation is " ,total_variation, "Vol% Points, the average accuracy is " ,total_accuracy, "%")
# Out:
#  The average variation is  2.299725788529036 Vol% Points, the average accuracy is  102.27873195624665 %

# %%
# Compute pairwise correlation of columns
# DataFrame.corr(method='pearson', min_periods=1)[source]
# Compute pairwise correlation of columns, excluding NA/null values.

# Parameters
# method{‘pearson’, ‘kendall’, ‘spearman’} or callable
# Method of correlation:
# pearson : standard correlation coefficient
# kendall : Kendall Tau correlation coefficient
# spearman : Spearman rank correlation
# callable: callable with input two 1d ndarrays
# and returning a float. Note that the returned matrix from corr will have 1 along the diagonals and will be symmetric regardless of the callable’s behavior.
# min_periodsint, optional
# Minimum number of observations required per pair of columns to have a valid result. Currently only available for Pearson and Spearman correlation.

TA_df.corr(method='pearson', min_periods=1)
# Out:
#                            TA.LAB.NC4.VOLPCT  TA.Charge.BPD  TA.OH.PSIG  \
# TA.LAB.NC4.VOLPCT                   1.000000      -0.049739   -0.038700
# TA.Charge.BPD                      -0.049739       1.000000    0.109065
# TA.OH.PSIG                         -0.038700       0.109065    1.000000
# TA.Tray4.F                          0.084384       0.144407    0.534599
# TA.OH.F                             0.058549       0.095405    0.510588
# TA.RECV.PCT                        -0.002043      -0.188348   -0.317600
# TA.RECV.PSIG                       -0.029297       0.154229    0.710397
# TA.REFLUX.BPD                      -0.044886       0.336843    0.163438
# TA.RECYCLE.TO.CONTACT.BPD          -0.018326       0.585825   -0.097758
# TA.RECYCLE.TO.CONTACT.F             0.030073      -0.038100    0.238164
# TA.TRAY39.F                         0.116923      -0.128984    0.048333
# TA.TRAY45.F                         0.032660      -0.252216   -0.062111
# TA.DP.PSIG                          0.000498       0.140057   -0.371669
# TA.BTM.PSIG                        -0.009530       0.221745    0.318849
# TA.BTM.LEVEL.PCT                   -0.001006       0.406248   -0.001837
# TA.BTM.REBOIL.OUT.F                -0.055530      -0.347708   -0.029754
# TA.TOP.REBOIL.OUT.F                 0.010200      -0.034595   -0.227273
# Date_Count                         -0.039681       0.813312    0.025170
#
#                            TA.Tray4.F   TA.OH.F  TA.RECV.PCT  TA.RECV.PSIG  \
# TA.LAB.NC4.VOLPCT            0.084384  0.058549    -0.002043     -0.029297
# TA.Charge.BPD                0.144407  0.095405    -0.188348      0.154229
# TA.OH.PSIG                   0.534599  0.510588    -0.317600      0.710397
# TA.Tray4.F                   1.000000  0.949735    -0.333435      0.703345
# TA.OH.F                      0.949735  1.000000    -0.270652      0.663218
# TA.RECV.PCT                 -0.333435 -0.270652     1.000000     -0.435357
# TA.RECV.PSIG                 0.703345  0.663218    -0.435357      1.000000
# TA.REFLUX.BPD                0.108882  0.207673    -0.106300      0.181477
# TA.RECYCLE.TO.CONTACT.BPD    0.113615  0.139345    -0.195313      0.152153
# TA.RECYCLE.TO.CONTACT.F      0.275982  0.231722    -0.393174      0.274469
# TA.TRAY39.F                  0.276142  0.201438    -0.128844      0.064820
# TA.TRAY45.F                 -0.038262  0.003222    -0.015769     -0.105122
# TA.DP.PSIG                  -0.080396 -0.082574     0.062624     -0.004064
# TA.BTM.PSIG                  0.297369  0.239505    -0.235192      0.460451
# TA.BTM.LEVEL.PCT             0.162306  0.094603    -0.252730      0.024797
# TA.BTM.REBOIL.OUT.F         -0.255242 -0.154241     0.296756     -0.047098
# TA.TOP.REBOIL.OUT.F         -0.199754 -0.304555     0.021099     -0.291323
# Date_Count                   0.139838  0.047640    -0.279603      0.101633
#
#                            TA.REFLUX.BPD  TA.RECYCLE.TO.CONTACT.BPD  \
# TA.LAB.NC4.VOLPCT              -0.044886                  -0.018326
# TA.Charge.BPD                   0.336843                   0.585825
# TA.OH.PSIG                      0.163438                  -0.097758
# TA.Tray4.F                      0.108882                   0.113615
# TA.OH.F                         0.207673                   0.139345
# TA.RECV.PCT                    -0.106300                  -0.195313
# TA.RECV.PSIG                    0.181477                   0.152153
# TA.REFLUX.BPD                   1.000000                   0.389453
# TA.RECYCLE.TO.CONTACT.BPD       0.389453                   1.000000
# TA.RECYCLE.TO.CONTACT.F         0.088163                   0.122934
# TA.TRAY39.F                    -0.113841                  -0.185986
# TA.TRAY45.F                    -0.103904                  -0.230220
# TA.DP.PSIG                     -0.044410                   0.149857
# TA.BTM.PSIG                     0.096099                   0.110175
# TA.BTM.LEVEL.PCT               -0.013767                   0.257694
# TA.BTM.REBOIL.OUT.F             0.006007                  -0.265034
# TA.TOP.REBOIL.OUT.F            -0.419338                  -0.199482
# Date_Count                      0.138271                   0.414298
#
#                            TA.RECYCLE.TO.CONTACT.F  TA.TRAY39.F  TA.TRAY45.F  \
# TA.LAB.NC4.VOLPCT                         0.030073     0.116923     0.032660
# TA.Charge.BPD                            -0.038100    -0.128984    -0.252216
# TA.OH.PSIG                                0.238164     0.048333    -0.062111
# TA.Tray4.F                                0.275982     0.276142    -0.038262
# TA.OH.F                                   0.231722     0.201438     0.003222
# TA.RECV.PCT                              -0.393174    -0.128844    -0.015769
# TA.RECV.PSIG                              0.274469     0.064820    -0.105122
# TA.REFLUX.BPD                             0.088163    -0.113841    -0.103904
# TA.RECYCLE.TO.CONTACT.BPD                 0.122934    -0.185986    -0.230220
# TA.RECYCLE.TO.CONTACT.F                   1.000000     0.138605     0.008194
# TA.TRAY39.F                               0.138605     1.000000     0.702470
# TA.TRAY45.F                               0.008194     0.702470     1.000000
# TA.DP.PSIG                               -0.114507    -0.023858    -0.016459
# TA.BTM.PSIG                               0.076049     0.058008    -0.043631
# TA.BTM.LEVEL.PCT                          0.065206     0.096794     0.039510
# TA.BTM.REBOIL.OUT.F                      -0.095758     0.093950     0.365842
# TA.TOP.REBOIL.OUT.F                      -0.094805     0.282290     0.407655
# Date_Count                               -0.051398     0.002021    -0.131075
#
#                            TA.DP.PSIG  TA.BTM.PSIG  TA.BTM.LEVEL.PCT  \
# TA.LAB.NC4.VOLPCT            0.000498    -0.009530         -0.001006
# TA.Charge.BPD                0.140057     0.221745          0.406248
# TA.OH.PSIG                  -0.371669     0.318849         -0.001837
# TA.Tray4.F                  -0.080396     0.297369          0.162306
# TA.OH.F                     -0.082574     0.239505          0.094603
# TA.RECV.PCT                  0.062624    -0.235192         -0.252730
# TA.RECV.PSIG                -0.004064     0.460451          0.024797
# TA.REFLUX.BPD               -0.044410     0.096099         -0.013767
# TA.RECYCLE.TO.CONTACT.BPD    0.149857     0.110175          0.257694
# TA.RECYCLE.TO.CONTACT.F     -0.114507     0.076049          0.065206
# TA.TRAY39.F                 -0.023858     0.058008          0.096794
# TA.TRAY45.F                 -0.016459    -0.043631          0.039510
# TA.DP.PSIG                   1.000000    -0.611787          0.024363
# TA.BTM.PSIG                 -0.611787     1.000000          0.134411
# TA.BTM.LEVEL.PCT             0.024363     0.134411          1.000000
# TA.BTM.REBOIL.OUT.F          0.068129    -0.121750         -0.472976
# TA.TOP.REBOIL.OUT.F          0.064685    -0.052044          0.236700
# Date_Count                   0.177676     0.257916          0.584127
#
#                            TA.BTM.REBOIL.OUT.F  TA.TOP.REBOIL.OUT.F  \
# TA.LAB.NC4.VOLPCT                    -0.055530             0.010200
# TA.Charge.BPD                        -0.347708            -0.034595
# TA.OH.PSIG                           -0.029754            -0.227273
# TA.Tray4.F                           -0.255242            -0.199754
# TA.OH.F                              -0.154241            -0.304555
# TA.RECV.PCT                           0.296756             0.021099
# TA.RECV.PSIG                         -0.047098            -0.291323
# TA.REFLUX.BPD                         0.006007            -0.419338
# TA.RECYCLE.TO.CONTACT.BPD            -0.265034            -0.199482
# TA.RECYCLE.TO.CONTACT.F              -0.095758            -0.094805
# TA.TRAY39.F                           0.093950             0.282290
# TA.TRAY45.F                           0.365842             0.407655
# TA.DP.PSIG                            0.068129             0.064685
# TA.BTM.PSIG                          -0.121750            -0.052044
# TA.BTM.LEVEL.PCT                     -0.472976             0.236700
# TA.BTM.REBOIL.OUT.F                   1.000000             0.038231
# TA.TOP.REBOIL.OUT.F                   0.038231             1.000000
# Date_Count                           -0.479824             0.253554
#
#                            Date_Count
# TA.LAB.NC4.VOLPCT           -0.039681
# TA.Charge.BPD                0.813312
# TA.OH.PSIG                   0.025170
# TA.Tray4.F                   0.139838
# TA.OH.F                      0.047640
# TA.RECV.PCT                 -0.279603
# TA.RECV.PSIG                 0.101633
# TA.REFLUX.BPD                0.138271
# TA.RECYCLE.TO.CONTACT.BPD    0.414298
# TA.RECYCLE.TO.CONTACT.F     -0.051398
# TA.TRAY39.F                  0.002021
# TA.TRAY45.F                 -0.131075
# TA.DP.PSIG                   0.177676
# TA.BTM.PSIG                  0.257916
# TA.BTM.LEVEL.PCT             0.584127
# TA.BTM.REBOIL.OUT.F         -0.479824
# TA.TOP.REBOIL.OUT.F          0.253554
# Date_Count                   1.000000
